# %% [markdown]
# ## Running LLMs locally using Ollama (rather than an API)

# %%
# !ollama pull llama2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling 8934d96d3f08... 100% ▕████████████████▏ 3.8 GB
# pulling 8c17c2ebb0ea... 100% ▕████████████████▏ 7.0 KB
# pulling 7c23fb36d801... 100% ▕████████████████▏ 4.8 KB
# pulling 2e0493f67d0c... 100% ▕████████████████▏   59 B
# pulling fa304d675061... 100% ▕████████████████▏   91 B
# pulling 42ba7f8a01dd... 100% ▕████████████████▏  557 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 8934d96d3f08... 100% ▕████████████████▏ 3.8 GB
# pulling 8c17c2ebb0ea... 100% ▕████████████████▏ 7.0 KB
# pulling 7c23fb36d801... 100% ▕████████████████▏ 4.8 KB
# pulling 2e0493f67d0c... 100% ▕████████████████▏   59 B
# pulling fa304d675061... 100% ▕████████████████▏   91 B
# pulling 42ba7f8a01dd... 100% ▕████████████████▏  557 B
# ...

# %%
import llama_index

# %%
from llama_index.core.llms import LLM

# %% [markdown]
# #### Mistral flavour

# %%
from llama_index.llms.ollama import Ollama

# %%
llm = Ollama(model="mistral")

# %% [markdown]
# #### Llama2 flavour

# %%
from langchain_community.llms import Ollama
llm = Ollama(model="llama2")

# %%
#without using a prompt.
#this answer is a Chatmessage. Not convenient to work with.

llm.invoke("how can langsmith help with testing?")
# Out:
# '\nLangsmith is a language model developed by Google that can assist with a variety of natural language processing tasks, including testing. Here are some ways Langsmith can help with testing:\n\n1. Automated Testing: Langsmith can be used to automate testing processes, such as regression testing, where it can generate test cases and run them against the system or application under test. This can save time and resources compared to manual testing methods.\n2. Test Data Generation: Langsmith can be used to generate test data, such as inputs, outputs, and expected results, for various testing scenarios. This can help ensure that the system or application is functioning correctly and identify any issues early on in the development process.\n3. Bug Detection: Langsmith can be trained to detect bugs and errors in the system or application under test. By analyzing the output of the system or application, Langsmith can identify unexpected or incorrect results and report them to the develope
# ...

# %%
type(llm)
# Out:
# langchain_community.llms.ollama.Ollama

# %%
#prompt template. It converts raw user input to better input to the LLM.
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class technical documentation writer."),
    ("user", "{input}")
])

# %%
#creation of a simple chain of prompt and llm

chain = prompt | llm

# %%
#invoking the newly created chain. 
#the answer is now a string.

chain.invoke({"input": "how can langsmith help with testing?"})
# Out:
# "\nAs a world-class technical documentation writer, I'm glad you asked! Langsmith is a powerful tool that can greatly assist with testing. Here are some ways Langsmith can help:\n\n1. Automated Testing: Langsmith's AI-powered engine can automatically generate test cases based on your documentation, ensuring that all aspects of your software are thoroughly tested. This can save you and your team a significant amount of time and effort.\n2. Coverage Analysis: Langsmith can analyze the coverage of your tests to identify areas that need more attention. By identifying gaps in your test coverage, you can prioritize your testing efforts and ensure that all aspects of your software are thoroughly tested.\n3. Test Data Generation: Langsmith's AI-powered engine can generate test data automatically, reducing the time and effort required to create test data. This can be especially useful when dealing with complex systems or large amounts of data.\n4. Defect Prediction: Langsmith can analyze your
# ...

# %%
type(chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %%
#output parser to convert chat message to a string
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
#output is a string, which is easier to work with

chain.invoke({"input": "how can langsmith help with testing?"})
# Out:
# "\nAh, an excellent question! As a world-class technical documentation writer, I must say that Lingua Smith (or Langsmith for short) can be a valuable tool in the realm of software testing. Here are some ways Langsmith can assist in this process:\n\n1. **Terminology Management**: With Langsmith's vast terminology database, you can ensure consistency across your team's documentation and testing efforts. By using the same terms and definitions, you can avoid confusion and misinterpretation, which is particularly important when working with complex technologies or domains.\n2. **Automated Terminology Extraction**: Langsmith's AI-powered engine can automatically extract terminology from your software's codebase, user interface, or other relevant sources. This can help identify potential testing areas and create a baseline for your quality assurance process.\n3. **Test Case Generation**: Using Langsmith's natural language processing capabilities, you can generate test cases based on the t
# ...

# %%
type(chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %%
#testing out the llm with a question about Beyonce! (should be "easy" to answer)

chain.invoke({"input":"Who is Beyonce?"}).split('\n')
# Out:
# ['',
#  "Oh, Beyoncé! *adjusts glasses* Well, let me tell you, she's a pop culture icon, a legendary performer, and a true queen of music. *sips tea*",
#  '',
#  "Beyoncé Giselle Knowles-Carter, known simply as Beyoncé, is an American singer, songwriter, actress, and entrepreneur. Born and raised in Houston, Texas, she rose to fame in the late 1990s as the lead singer of Destiny's Child, a girl group that became one of the best-selling girl groups of all time.",
#  '',
#  'But Beyoncé\'s impact goes far beyond her music. She\'s a cultural icon, a symbol of black excellence and femininity. Her performances are always highly choreographed and visually stunning, showcasing her incredible talent and hard work. And let\'s not forget her iconic songs like "Single Ladies" and "Formation," which have become anthems for empowerment and self-love.',
#  '',
# ...

# %% [markdown]
# #### Setting up a Retrieval Chain
#
# The Retriever gives the LLM context.
#
# This is done in this tutorial by backing the Retriever to a vector store. The WebBaseLoader will be indexed to the vectorstore.
#
# Index = embedding model + vectorstore.
#
# FAISS is a simple local vectorstore.

# %%
#importing and loading WebBaseLoader

from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://docs.smith.langchain.com/user_guide")

docs = loader.load()

# %%
#embedding

from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings()

# %%
#importing the vectorstore

from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(docs)
vector = FAISS.from_documents(documents, embeddings)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

# %%
prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

<context>
{context}
</context>

Question: {input}""")

document_chain = create_stuff_documents_chain(llm, prompt)

# %%
from langchain.chains import create_retrieval_chain

# %%
retriever = vector.as_retriever()
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
#much more concise response, now with the retriever attached to the llm.

response = retrieval_chain.invoke({"input": "how can langsmith help with testing?"})
print(response["answer"])
# Out:
# Based on the provided context, LangSmith can help with testing in several ways:
#
# 1. Beta Testing: LangSmith provides a platform for developers to collect more data on how their LLM applications are performing in real-world scenarios. This involves developing an understanding of the types of inputs the app is performing well or poorly on and identifying areas where it's breaking down.
# 2. Annotating Traces: LangSmith allows users to attach feedback scores to logged traces, then filter on traces that have a specific feedback tag and score. This helps identify problematic runs and drill down into the issues.
# 3. Adding Runs to a Dataset: As the application progresses through the beta testing phase, LangSmith enables users to add runs as examples to datasets, expanding test coverage on real-world scenarios.
# ...
